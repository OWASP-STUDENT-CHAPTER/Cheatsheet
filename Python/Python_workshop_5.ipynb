# %%
import pandas as pd

# %%
d1 ={'Age' : [23, 33, 12, 45], 'Name' : ['Bakul', 'Niket', 'Yash', 'Ishaan']}
d2 = pd.DataFrame(d1)  #table mein convert kar diya
print(d2)
# Out:
#    Age    Name
# 0   23   Bakul
# 1   33   Niket
# 2   12    Yash
# 3   45  Ishaan

# %%
print(d2[:]['Name'])
# Out:
# 0     Bakul
# 1     Niket
# 2      Yash
# 3    Ishaan
# Name: Name, dtype: object

# %%
d3 = pd.DataFrame(d1, index = ['Roll 1', 'Roll 2', 'Roll 3', 'Roll 4'])
print(d3)
# Out:
#         Age    Name
# Roll 1   23   Bakul
# Roll 2   33   Niket
# Roll 3   12    Yash
# Roll 4   45  Ishaan

# %%
d3.loc(['Roll 3']['Name'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-cea1a35f29af> in <module>
# ----> 1 d3.loc(['Roll 3']['Name'])
#
# TypeError: list indices must be integers or slices, not str

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hp'

# %%
ufo = pd.read_csv('ufo.csv')
ufo.shape
# Out:
# (80332, 11)

# %%
ufo
# Out:
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# ...

# %%
ufo.head() #shows initial 5 rows
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# ...

# %%
ufo.tail() #shows last 5 rows
# Out:
#              datetime       city state country   shape duration (seconds)  \
# 80327  9/9/2013 21:15  nashville    tn      us   light              600.0
# 80328  9/9/2013 22:00      boise    id      us  circle             1200.0
# 80329  9/9/2013 22:00       napa    ca      us   other             1200.0
# 80330  9/9/2013 22:20     vienna    va      us  circle                5.0
# 80331  9/9/2013 23:00     edmond    ok      us   cigar             1020.0
#
#       duration (hours/min)                                           comments  \
# 80327           10 minutes  Round from the distance/slowly changing colors...
# 80328           20 minutes  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...
# 80329                 hour                                       Napa UFO&#44
# 80330            5 seconds  Saw a five gold lit cicular craft moving fastl...
# 80331           17 minutes  2 witnesses 2  miles apart&#44 Red &amp; White...
#
#       date posted   latitude  longitude
# ...

# %%
ufo.head(20)  #shows top 20 rows
# Out:
#             datetime                  city state country     shape  \
# 0   10/10/1949 20:30            san marcos    tx      us  cylinder
# 1   10/10/1949 21:00          lackland afb    tx     NaN     light
# 2   10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3   10/10/1956 21:00                  edna    tx      us    circle
# 4   10/10/1960 20:00               kaneohe    hi      us     light
# 5   10/10/1961 19:00               bristol    tn      us    sphere
# 6   10/10/1965 21:00    penarth (uk/wales)   NaN      gb    circle
# 7   10/10/1965 23:45               norwalk    ct      us      disk
# 8   10/10/1966 20:00             pell city    al      us      disk
# 9   10/10/1966 21:00              live oak    fl      us      disk
# 10  10/10/1968 13:00             hawthorne    ca      us    circle
# 11  10/10/1968 19:00               brevard    nc      us  fireball
# 12  10/10/1970 16:00              bellmore    ny      us      disk
# ...

# %%
ufo = ufo.drop(['latitude'], axis = 1)  #drop ka use tab karna hai jab koi row ya column udana hai
# & axis = 1 ka matlab hai ki hum latitude naam ka column hatana chahte hain 
# & aagar axis = 0 likhunga to latitude naam ka row search karega use delete karne ke liye

# %%
ufo = ufo.drop(['comments'], axis = 1)

# %%
ufo
# Out:
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min) date posted  longitude
# ...

# %%
ufo = ufo.drop(['date posted', 'longitude '], axis = 1)

# %%
ufo
# Out:
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)
# 0                   2700           45 minutes
# ...

# %%
ufo.dtypes #to know the data types of the columns
# Out:
# datetime                object
# city                    object
# state                   object
# country                 object
# shape                   object
# duration (seconds)      object
# duration (hours/min)    object
# dtype: object

# %%
ufo[ufo['state'] == 'tx']  #to see the data that has state as tx
# Out:
#                datetime          city state country      shape  \
# 0      10/10/1949 20:30    san marcos    tx      us   cylinder
# 1      10/10/1949 21:00  lackland afb    tx     NaN      light
# 3      10/10/1956 21:00          edna    tx      us     circle
# 25     10/10/1977 12:00   san antonio    tx      us      other
# 32     10/10/1980 19:00       houston    tx      us     sphere
# ...                 ...           ...   ...     ...        ...
# 80229    9/9/2008 20:00       el paso    tx      us      light
# 80240    9/9/2009 19:32    fort worth    tx      us     circle
# 80268    9/9/2010 21:00        austin    tx      us      light
# 80292    9/9/2012 09:14  rancho viejo    tx      us  formation
# 80317    9/9/2013 12:34    cedar park    tx      us      cigar
#
#       duration (seconds) duration (hours/min)
# 0                   2700           45 minutes
# 1                   7200              1-2 hrs
# 3                     20             1/2 hour
# ...

# %%
ufo = ufo.drop_duplicates()  #to remove any duplicate entery in the data

# %%
ufo
# Out:
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)
# 0                   2700           45 minutes
# ...

# %%
ufo.columns
# Out:
# Index(['datetime', 'city', 'state', 'country', 'shape', 'duration (seconds)',
#        'duration (hours/min)'],
#       dtype='object')

# %%
ufo.info
# Out:
# <bound method DataFrame.info of                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)
# 0                   2700           45 minutes
# ...

# %%
ufo.dropna() #it removes all those fields jis mein koi b column mein entry missing thi
# Out:
#                datetime        city state country     shape  \
# 0      10/10/1949 20:30  san marcos    tx      us  cylinder
# 3      10/10/1956 21:00        edna    tx      us    circle
# 4      10/10/1960 20:00     kaneohe    hi      us     light
# 5      10/10/1961 19:00     bristol    tn      us    sphere
# 7      10/10/1965 23:45     norwalk    ct      us      disk
# ...                 ...         ...   ...     ...       ...
# 80327    9/9/2013 21:15   nashville    tn      us     light
# 80328    9/9/2013 22:00       boise    id      us    circle
# 80329    9/9/2013 22:00        napa    ca      us     other
# 80330    9/9/2013 22:20      vienna    va      us    circle
# 80331    9/9/2013 23:00      edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)
# 0                   2700           45 minutes
# 3                     20             1/2 hour
# 4                    900           15 minutes
# 5                    300            5 minutes
# ...
